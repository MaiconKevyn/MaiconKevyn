# %% [markdown]
# <a href="https://colab.research.google.com/github/MaiconKevyn/MaiconKevyn/blob/main/cartesiana_para_polar2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
def cartesiana2polar_2(x,y):

  r = math.sqrt(x**2+y**2)
  theta = math.atan2(y,x)

  return r,theta*180./math.pi

print(cartesiana2polar_2(-2,-2))
# Out:
# (2.8284271247461903, -135.0)

# %% [markdown]
# # Nova seção
